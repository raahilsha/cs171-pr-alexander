# %%
# %autosave 60
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, mpld3
import seaborn as sns
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# 1. Does CINC ratio predict win/loose?
#     length?
#     death?

# %%
wars = pd.read_csv('./Inter-StateWarData_v4.0.csv',index_col=0)
nmc_raw = pd.read_csv('./NMC_v4_0.csv')
nmc=nmc_raw.set_index(['year','ccode'])
nmc = nmc_raw[['cinc']]
ccodes = pd.read_csv('./COW country codes.csv', index_col=1)

# %%
print wars[wars.Outcome.isin([1,2,3])].index.unique().shape
print wars.index.unique().shape
# Out:
# (79L,)
# (95L,)

# %%
def get_cinc_ratio(warNum):
    
    year = wars.ix[warNum].StartYear1.irow(0)
    initiator = wars.ix[warNum][wars.ix[warNum]['Initiator'] == 1]
    defender = wars.ix[warNum][wars.ix[warNum]['Initiator'] == 2]
    ratio = nmc.ix[initiator.ccode.irow(0)].ix[year][0] / nmc.ix[defender.ccode.irow(0)].ix[year][0]
    return ratio
wars['cinc_ratio'] = wars.index.to_series().apply(get_cinc_ratio)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-b40ce8fbb827> in <module>()
#       6     ratio = nmc.ix[initiator.ccode.irow(0)].ix[year][0] / nmc.ix[defender.ccode.irow(0)].ix[year][0]
#       7     return ratio
# ----> 8 wars['cinc_ratio'] = wars.index.to_series().apply(get_cinc_ratio)
#
# C:\Anaconda\lib\site-packages\pandas\core\series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2056             values = lib.map_infer(values, lib.Timestamp)
#    2057
# -> 2058         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2059         if len(mapped) and isinstance(mapped[0], Series):
#    2060             from pandas.core.frame import DataFrame
#
# C:\Anaconda\lib\site-packages\pandas\lib.pyd in pandas.lib.map_infer (pandas\lib.c:56997)()
#
# <ipython-input-4-b40ce8fbb827> in get_cinc_ratio(warNum)
#       4     initiator = wars.ix[warNum][wars.ix[warNum]['Initiator'] == 1]
#       5     defender = wars.ix[warNum][wars.ix[warNum]['Initiator'] == 2]
# ----> 6     ratio = nmc.ix[initiator.ccode.irow(0)].ix[year][0] / nmc.ix[defender.ccode.irow(0)].ix[year][0]
#       7     return ratio
#       8 wars['cinc_ratio'] = wars.index.to_series().apply(get_cinc_ratio)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#      70             return self._getitem_tuple(key)
#      71         else:
# ---> 72             return self._getitem_axis(key, axis=0)
#      73
#      74     def _get_label(self, label, axis=0):
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#     924                 # this is the fallback! (for a non-float, non-integer index)
#     925                 if not labels.is_floating() and not labels.is_integer():
# --> 926                     return self._get_loc(key, axis=axis)
#     927
#     928             return self._get_label(key, axis=axis)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _get_loc(self, key, axis)
#      89
#      90     def _get_loc(self, key, axis=0):
# ---> 91         return self.obj._ixs(key, axis=axis)
#      92
#      93     def _slice(self, obj, axis=0, typ=None):
#
# C:\Anaconda\lib\site-packages\pandas\core\series.pyc in _ixs(self, i, axis)
#     481             values = self.values
#     482             if isinstance(values, np.ndarray):
# --> 483                 return _index.get_value_at(values, i)
#     484             else:
#     485                 return values[i]
#
# C:\Anaconda\lib\site-packages\pandas\index.pyd in pandas.index.get_value_at (pandas\index.c:2341)()
#
# C:\Anaconda\lib\site-packages\pandas\index.pyd in util.get_value_at (pandas\index.c:15270)()
#
# IndexError: index out of bounds

# %%
wars['StartDate'] = (wars.StartYear1.apply(str) + "-" + wars.StartMonth1.apply(str) + "-" + wars.StartDay1.apply(str)).apply(pd.Timestamp)
wars['EndDate'] = (wars.EndYear1.apply(str) + "-" + wars.EndMonth1.apply(str) + "-" + wars.EndDay1.apply(str)).apply(pd.Timestamp)
wars['length'] = (wars.EndDate - wars.StartDate).dt.days

# %%
wars.set_index(['StartYear1']).BatDeath.plot()
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_
0], [1914.0, 908371.0], [1914.0, 300.0], [1916.0, 7222.0], [1914.0, 325000.0], [1914.0, 13716.0], [1914.0, 1773700.0], [1917.0, 5000.0], [1916.0, 335706.0], [1914.0, 1200000.0], [1914.0, 1385000.0], [1915.0, 650000.0], [1917.0, 116516.0], [1918.0, 3600.0], [1918.0, 150.0], [1918.0, 8000.0], [1918.0, 450.0], [1918.0, 8000.0], [1919.0, 750.0], [1919.0, 1000.0], [1918.0, 3046.0], [1919.0, 60000.0], [1919.0, 40000.0], [1919.0, 6000.0], [1 ...

# %%
print wars[(wars.Initiator == 1) & (wars.Outcome == 1)].shape[0]
print wars[(wars.Initiator == 1) & (wars.Outcome == 2)].shape[0]
# Out:
# 61
# 27

# %%
print wars[(wars.Initiator == 1) & (wars.Outcome == 1) & (wars.cinc_ratio > 1)].shape[0]/float(wars[(wars.Initiator == 1) & (wars.cinc_ratio > 1)].shape[0])
print wars[(wars.Initiator == 1) & (wars.Outcome == 1) & (wars.cinc_ratio < 1)].shape[0]/float(wars[(wars.Initiator == 1) & (wars.cinc_ratio < 1)].shape[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a74e355d83fc> in <module>()
# ----> 1 print wars[(wars.Initiator == 1) & (wars.Outcome == 1) & (wars.cinc_ratio > 1)].shape[0]/float(wars[(wars.Initiator == 1) & (wars.cinc_ratio > 1)].shape[0])
#       2 print wars[(wars.Initiator == 1) & (wars.Outcome == 1) & (wars.cinc_ratio < 1)].shape[0]/float(wars[(wars.Initiator == 1) & (wars.cinc_ratio < 1)].shape[0])
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cinc_ratio'

# %%
wars[(wars.Initiator == 1)].set_index(['StartYear1']).cinc_ratio.plot()
mpld3.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1f2868f1b1d5> in <module>()
# ----> 1 wars[(wars.Initiator == 1)].set_index(['StartYear1']).cinc_ratio.plot()
#       2 mpld3.display()
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cinc_ratio'

# %%
wars.set_index(['BatDeath']).sort().cinc_ratio.plot()
mpld3.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cebac1bbd098> in <module>()
# ----> 1 wars.set_index(['BatDeath']).sort().cinc_ratio.plot()
#       2 mpld3.display()
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cinc_ratio'

# %%
def init(raw):
    ccode = raw.ix[0]
    return wars[wars.ccode == ccode].groupby('Initiator').size()[1]

# %%
aggr = pd.DataFrame(index=nmc.reset_index().set_index('ccode').index.unique()).reset_index()

# %%
aggr['aggresive'] = aggr.apply(init)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8bb6237104be> in <module>()
# ----> 1 aggr['aggresive'] = aggr.apply(init)
#
# NameError: name 'aggr' is not defined

# %%
nmc.swaplevel(0,1,axis=0).ix[1850].sort('cinc').plot(kind='barh')
mpld3.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-502901991f21> in <module>()
# ----> 1 nmc.swaplevel(0,1,axis=0).ix[1850].sort('cinc').plot(kind='barh')
#       2 mpld3.display()
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.pyc in swaplevel(self, i, j, axis)
#    2966         axis = self._get_axis_number(axis)
#    2967         if axis == 0:
# -> 2968             result.index = result.index.swaplevel(i, j)
#    2969         else:
#    2970             result.columns = result.columns.swaplevel(i, j)
#
# AttributeError: 'Int64Index' object has no attribute 'swaplevel'

# %%
nmc_raw['name'] = nmc_raw.apply(lambda x: ccodes.StateNme.ix[x.ccode],axis=1)

# %%
js = nmc_raw.set_index(['year'])[['name','cinc']]
def countries(year):
    return js.loc[1816].to_json(orient='records')

# %%
result = ''
for ind in js.index:
    result = result + "{year:" + str(ind) + "," + countries(ind) + "}"
